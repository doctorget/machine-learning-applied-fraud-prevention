# %%
import pandas as pd

# %%
dados = pd.read_csv('dados/train_transaction.csv')
dados.head(50)
# Out:
#     TransactionID  isFraud  TransactionDT  TransactionAmt ProductCD  card1  \
# 0         2987000        0          86400          68.500         W  13926
# 1         2987001        0          86401          29.000         W   2755
# 2         2987002        0          86469          59.000         W   4663
# 3         2987003        0          86499          50.000         W  18132
# 4         2987004        0          86506          50.000         H   4497
# 5         2987005        0          86510          49.000         W   5937
# 6         2987006        0          86522         159.000         W  12308
# 7         2987007        0          86529         422.500         W  12695
# 8         2987008        0          86535          15.000         H   2803
# 9         2987009        0          86536         117.000         W  17399
# 10        2987010        0          86549          75.887         C  16496
# ...

# %%
dados.shape[0]
# Out:
# 590540

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 590540 entries, 0 to 590539
# Columns: 394 entries, TransactionID to V339
# dtypes: float64(376), int64(4), object(14)
# memory usage: 1.7+ GB

# %%
dados[dados['isFraud'] == 1]
# Out:
#         TransactionID  isFraud  TransactionDT  TransactionAmt ProductCD  \
# 203           2987203        1          89760         445.000         W
# 240           2987240        1          90193          37.098         C
# 243           2987243        1          90246          37.098         C
# 245           2987245        1          90295          37.098         C
# 288           2987288        1          90986         155.521         C
# ...               ...      ...            ...             ...       ...
# 590361        3577361        1       15807368        1224.000         W
# 590364        3577364        1       15807516          69.964         C
# 590368        3577368        1       15807677         100.000         H
# 590372        3577372        1       15807758         117.000         W
# 590526        3577526        1       15810876         250.000         R
#
#         card1  card2  card3             card4  card5  ... V330  V331  V332  \
# ...

# %%
dados.shape
# Out:
# (590540, 394)

# %%
dados.drop('TransactionID', axis= 1, inplace = True)

# %%
dados.head(10)
# Out:
#    isFraud  TransactionDT  TransactionAmt ProductCD  card1  card2  card3  \
# 0        0          86400            68.5         W  13926    NaN  150.0
# 1        0          86401            29.0         W   2755  404.0  150.0
# 2        0          86469            59.0         W   4663  490.0  150.0
# 3        0          86499            50.0         W  18132  567.0  150.0
# 4        0          86506            50.0         H   4497  514.0  150.0
# 5        0          86510            49.0         W   5937  555.0  150.0
# 6        0          86522           159.0         W  12308  360.0  150.0
# 7        0          86529           422.5         W  12695  490.0  150.0
# 8        0          86535            15.0         H   2803  100.0  150.0
# 9        0          86536           117.0         W  17399  111.0  150.0
#
#         card4  card5   card6  ...  V330  V331  V332  V333 V334 V335  V336  \
# 0    discover  142.0  credit  ...   NaN   NaN   NaN   NaN  NaN  NaN   NaN
# ...

# %%
dados.duplicated().sum()
# Out:
# 3

# %%
dados.isnull().sum()
# Out:
# isFraud                0
# TransactionDT          0
# TransactionAmt         0
# ProductCD              0
# card1                  0
#                    ...
# V335              508189
# V336              508189
# V337              508189
# V338              508189
# V339              508189
# Length: 393, dtype: int64

# %%
dados.drop_duplicates(keep=False,inplace=True)

# %%
dados.duplicated().sum()
# Out:
# 0

# %%
for i in range(30):
    dados.drop('V3{}'.format(i), axis= 1, inplace = True)

# %%
dados.head(10)
# Out:
#    isFraud  TransactionDT  TransactionAmt ProductCD  card1  card2  card3  \
# 0        0          86400            68.5         W  13926    NaN  150.0
# 1        0          86401            29.0         W   2755  404.0  150.0
# 2        0          86469            59.0         W   4663  490.0  150.0
# 3        0          86499            50.0         W  18132  567.0  150.0
# 4        0          86506            50.0         H   4497  514.0  150.0
# 5        0          86510            49.0         W   5937  555.0  150.0
# 6        0          86522           159.0         W  12308  360.0  150.0
# 7        0          86529           422.5         W  12695  490.0  150.0
# 8        0          86535            15.0         H   2803  100.0  150.0
# 9        0          86536           117.0         W  17399  111.0  150.0
#
#         card4  card5   card6  ...  V330  V331  V332  V333 V334 V335  V336  \
# 0    discover  142.0  credit  ...   NaN   NaN   NaN   NaN  NaN  NaN   NaN
# ...

# %%
dados.drop('V330', axis= 1, inplace = True)

# %%
dados.head(10)
# Out:
#    isFraud  TransactionDT  TransactionAmt ProductCD  card1  card2  card3  \
# 0        0          86400            68.5         W  13926    NaN  150.0
# 1        0          86401            29.0         W   2755  404.0  150.0
# 2        0          86469            59.0         W   4663  490.0  150.0
# 3        0          86499            50.0         W  18132  567.0  150.0
# 4        0          86506            50.0         H   4497  514.0  150.0
# 5        0          86510            49.0         W   5937  555.0  150.0
# 6        0          86522           159.0         W  12308  360.0  150.0
# 7        0          86529           422.5         W  12695  490.0  150.0
# 8        0          86535            15.0         H   2803  100.0  150.0
# 9        0          86536           117.0         W  17399  111.0  150.0
#
#         card4  card5   card6  ...  V309  V331  V332  V333 V334 V335  V336  \
# 0    discover  142.0  credit  ...   0.0   NaN   NaN   NaN  NaN  NaN   NaN
# ...

# %%
dados.shape
# Out:
# (590534, 362)

# %%
dados.notnull().sum()
# Out:
# isFraud           590534
# TransactionDT     590534
# TransactionAmt    590534
# ProductCD         590534
# card1             590534
#                    ...
# V335               82351
# V336               82351
# V337               82351
# V338               82351
# V339               82351
# Length: 362, dtype: int64

# %%
dados[dados['V335'].notnull()]
# Out:
#         isFraud  TransactionDT  TransactionAmt ProductCD  card1  card2  card3  \
# 4             0          86506            50.0         H   4497  514.0  150.0
# 8             0          86535            15.0         H   2803  100.0  150.0
# 16            0          86620            30.0         H   1790  555.0  150.0
# 17            0          86668           100.0         H  11492  111.0  150.0
# 22            0          86786            50.0         H   1724  583.0  150.0
# ...         ...            ...             ...       ...    ...    ...    ...
# 590465        0       15809790           250.0         R  13309  399.0  150.0
# 590495        0       15810221           100.0         H   9749  181.0  150.0
# 590506        0       15810402           200.0         H  16075  514.0  150.0
# 590526        1       15810876           250.0         R   1214  174.0  150.0
# 590531        0       15810935           400.0         R   6019  583.0  150.0
#
# ...

# %%
for i in range(40,100):
    dados.drop('V{}'.format(i), axis= 1, inplace = True)

# %%
dados.drop('V299', axis= 1, inplace = True)

# %%
dados.head(10)
# Out:
#    isFraud  TransactionDT  TransactionAmt ProductCD  card1  card2  card3  \
# 0        0          86400            68.5         W  13926    NaN  150.0
# 1        0          86401            29.0         W   2755  404.0  150.0
# 2        0          86469            59.0         W   4663  490.0  150.0
# 3        0          86499            50.0         W  18132  567.0  150.0
# 4        0          86506            50.0         H   4497  514.0  150.0
# 5        0          86510            49.0         W   5937  555.0  150.0
# 6        0          86522           159.0         W  12308  360.0  150.0
# 7        0          86529           422.5         W  12695  490.0  150.0
# 8        0          86535            15.0         H   2803  100.0  150.0
# 9        0          86536           117.0         W  17399  111.0  150.0
#
#         card4  card5   card6  ...    D15   M1   M2   M3   M4   M5   M6   M7  \
# 0    discover  142.0  credit  ...    0.0    T    T    T   M2    F    T  NaN
# ...

# %%
dados_aux = pd.DataFrame(dados[['isFraud', 'TransactionDT', 'TransactionAmt', 'ProductCD', 'card1', 'card2', 'card3', 'card4', 'card5', 'card6','addr1','addr2','dist1',]])

# %%
dados_aux.head(25)
# Out:
#     isFraud  TransactionDT  TransactionAmt ProductCD  card1  card2  card3  \
# 0         0          86400          68.500         W  13926    NaN  150.0
# 1         0          86401          29.000         W   2755  404.0  150.0
# 2         0          86469          59.000         W   4663  490.0  150.0
# 3         0          86499          50.000         W  18132  567.0  150.0
# 4         0          86506          50.000         H   4497  514.0  150.0
# 5         0          86510          49.000         W   5937  555.0  150.0
# 6         0          86522         159.000         W  12308  360.0  150.0
# 7         0          86529         422.500         W  12695  490.0  150.0
# 8         0          86535          15.000         H   2803  100.0  150.0
# 9         0          86536         117.000         W  17399  111.0  150.0
# 10        0          86549          75.887         C  16496  352.0  117.0
# 11        0          86555          16.495         C   4461  375.0  185.0
# ...

# %%
dados_aux.notnull().sum()
# Out:
# isFraud           590504
# TransactionDT     590504
# TransactionAmt    590504
# ProductCD         590504
# card1             590504
# card2             581571
# card3             588939
# card4             588927
# card5             586245
# card6             588933
# addr1             524798
# addr2             524798
# dist1             238252
# dtype: int64

# %%
dados_aux = dados_aux[dados_aux['dist1'].notnull()]

# %%
dados_aux.drop_duplicates(keep=False,inplace=True)

# %%
dados[dados.columns[29:]]
# Out:
#         C14     D1     D2    D3    D4   D5  D6  D7  D8  D9  ...    D15   M1  \
# 0       1.0   14.0    NaN  13.0   NaN  NaN NaN NaN NaN NaN  ...    0.0    T
# 1       1.0    0.0    NaN   NaN   0.0  NaN NaN NaN NaN NaN  ...    0.0  NaN
# 2       1.0    0.0    NaN   NaN   0.0  NaN NaN NaN NaN NaN  ...  315.0    T
# 3       1.0  112.0  112.0   0.0  94.0  0.0 NaN NaN NaN NaN  ...  111.0  NaN
# 4       1.0    0.0    NaN   NaN   NaN  NaN NaN NaN NaN NaN  ...    NaN  NaN
# ...     ...    ...    ...   ...   ...  ...  ..  ..  ..  ..  ...    ...  ...
# 590535  2.0   29.0   29.0  30.0   NaN  NaN NaN NaN NaN NaN  ...   56.0    T
# 590536  1.0    0.0    NaN   NaN   0.0  NaN NaN NaN NaN NaN  ...    0.0    T
# 590537  1.0    0.0    NaN   NaN   0.0  NaN NaN NaN NaN NaN  ...    0.0    T
# 590538  1.0   22.0   22.0   0.0  22.0  0.0 NaN NaN NaN NaN  ...   22.0    T
# 590539  1.0    0.0    NaN   0.0   1.0  0.0 NaN NaN NaN NaN  ...    1.0    T
#
#          M2   M3   M4   M5   M6   M7   M8   M9
# ...

# %%
a_trocar = {
    'discover': 1,
    'visa':2,
    'mastercard':3,
    'american express':4
}
dados_aux.card4 = dados_aux.card4.map(a_trocar)

# %%
dados_aux.duplicated().sum()
# Out:
# 0

# %%
dados_aux
# Out:
#         isFraud  TransactionDT  TransactionAmt ProductCD  card1  card2  card3  \
# 0             0          86400           68.50         W  13926    NaN  150.0
# 2             0          86469           59.00         W   4663  490.0  150.0
# 5             0          86510           49.00         W   5937  555.0  150.0
# 6             0          86522          159.00         W  12308  360.0  150.0
# 9             0          86536          117.00         W  17399  111.0  150.0
# ...         ...            ...             ...       ...    ...    ...    ...
# 590522        0       15810823           54.50         W   3166  559.0  150.0
# 590525        0       15810866           57.95         W  11942  570.0  150.0
# 590533        0       15811029          107.95         W  13071  321.0  150.0
# 590535        0       15811047           49.00         W   6550    NaN  150.0
# 590538        0       15811088          117.00         W   7826  481.0  150.0
#
# ...

# %%
dados.describe()
# Out:
#             isFraud  TransactionDT  TransactionAmt          card1  \
# count  590504.00000   5.905040e+05   590504.000000  590504.000000
# mean        0.03498   7.372207e+06      135.011530    9898.881606
# std         0.18373   4.617325e+06      239.139433    4901.188546
# min         0.00000   8.640000e+04        0.251000    1000.000000
# 25%         0.00000   3.026905e+06       43.321000    6019.000000
# 50%         0.00000   7.305900e+06       68.758000    9678.000000
# 75%         0.00000   1.124708e+07      125.000000   14184.000000
# max         1.00000   1.581113e+07    31937.391000   18396.000000
#
#                card2          card3          card5          addr1  \
# count  581571.000000  588939.000000  586245.000000  524798.000000
# mean      362.557002     153.195120     199.277812     290.735475
# std       157.792911      11.336763      41.245279     101.742026
# min       100.000000     100.000000     100.000000     100.000000
# ...

# %%
trocar = {
    'credit':1,
    'debit':0
}
dados_aux.card6 = dados_aux.card6.map(trocar)
dados_aux.head(10)
# Out:
#     isFraud  TransactionDT  TransactionAmt ProductCD  card1  card2  card3  \
# 0         0          86400           68.50         W  13926    NaN  150.0
# 2         0          86469           59.00         W   4663  490.0  150.0
# 5         0          86510           49.00         W   5937  555.0  150.0
# 6         0          86522          159.00         W  12308  360.0  150.0
# 9         0          86536          117.00         W  17399  111.0  150.0
# 15        0          86618           57.95         W   7055  555.0  150.0
# 18        0          86725           47.95         W   4663  490.0  150.0
# 20        0          86761           39.00         W   7875  314.0  150.0
# 23        0          86808          107.95         W   2392  360.0  150.0
# 27        0          86972           47.95         W  11307  321.0  150.0
#
#     card4  card5  card6  addr1  addr2  dist1
# 0     1.0  142.0    1.0  315.0   87.0   19.0
# 2     2.0  166.0    0.0  330.0   87.0  287.0
# ...

# %%
dados_aux.describe()
# Out:
#              isFraud  TransactionDT  TransactionAmt          card1  \
# count  238252.000000   2.382520e+05   238252.000000  238252.000000
# mean        0.019941   7.872392e+06      142.611665    9891.089506
# std         0.139798   4.521230e+06      247.034496    4853.193440
# min         0.000000   8.640000e+04        2.000000    1001.000000
# 25%         0.000000   3.866066e+06       49.000000    6184.250000
# 50%         0.000000   7.774593e+06       77.950000    9680.000000
# 75%         0.000000   1.172300e+07      140.500000   13844.000000
# max         1.000000   1.581109e+07    31937.391000   18395.000000
#
#                card2          card3          card4          card5  card6  \
# count  234355.000000  237921.000000  237921.000000  237028.000000    0.0
# mean      353.847373     149.998083       2.313827     202.862215    NaN
# std       155.491531       0.925951       0.484458      39.224273    NaN
# ...

# %%
dados.duplicated().sum()
# Out:
# 20

# %%
dados.drop_duplicates(keep=False,inplace=True)

# %%
dados.duplicated().sum()
# Out:
# 0

# %%
dados.head(5)
# Out:
#    isFraud  TransactionDT  TransactionAmt ProductCD  card1  card2  card3  \
# 0        0          86400            68.5         W  13926    NaN  150.0
# 1        0          86401            29.0         W   2755  404.0  150.0
# 2        0          86469            59.0         W   4663  490.0  150.0
# 3        0          86499            50.0         W  18132  567.0  150.0
# 4        0          86506            50.0         H   4497  514.0  150.0
#
#         card4  card5   card6  ...    D15   M1   M2   M3   M4   M5   M6   M7  \
# 0    discover  142.0  credit  ...    0.0    T    T    T   M2    F    T  NaN
# 1  mastercard  102.0  credit  ...    0.0  NaN  NaN  NaN   M0    T    T  NaN
# 2        visa  166.0   debit  ...  315.0    T    T    T   M0    F    F    F
# 3  mastercard  117.0   debit  ...  111.0  NaN  NaN  NaN   M0    T    F  NaN
# 4  mastercard  102.0  credit  ...    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#     M8   M9
# 0  NaN  NaN
# 1  NaN  NaN
# 2    F    F
# 3  NaN  NaN
# ...

# %%
dados_aux.head(10)
# Out:
#     isFraud  TransactionDT  TransactionAmt ProductCD  card1  card2  card3  \
# 0         0          86400           68.50         W  13926    NaN  150.0
# 2         0          86469           59.00         W   4663  490.0  150.0
# 5         0          86510           49.00         W   5937  555.0  150.0
# 6         0          86522          159.00         W  12308  360.0  150.0
# 9         0          86536          117.00         W  17399  111.0  150.0
# 15        0          86618           57.95         W   7055  555.0  150.0
# 18        0          86725           47.95         W   4663  490.0  150.0
# 20        0          86761           39.00         W   7875  314.0  150.0
# 23        0          86808          107.95         W   2392  360.0  150.0
# 27        0          86972           47.95         W  11307  321.0  150.0
#
#     card4  card5  card6  addr1  addr2  dist1
# 0     1.0  142.0    1.0  315.0   87.0   19.0
# 2     2.0  166.0    0.0  330.0   87.0  287.0
# ...

# %%
dados_aux.ProductCD.value_counts()
# Out:
# W    238214
# Name: ProductCD, dtype: int64

# %%
dados_aux.ProductCD
# Out:
# 0         W
# 2         W
# 5         W
# 6         W
# 9         W
#          ..
# 590522    W
# 590525    W
# 590533    W
# 590535    W
# 590538    W
# Name: ProductCD, Length: 238214, dtype: object

# %%
troca = {
    'W':1
}

dados_aux.ProductCD = dados_aux.ProductCD.map(troca)

# %%
dados_aux.head(10)
# Out:
#     isFraud  TransactionDT  TransactionAmt  ProductCD  card1  card2  card3  \
# 0         0          86400           68.50          1  13926    NaN  150.0
# 2         0          86469           59.00          1   4663  490.0  150.0
# 5         0          86510           49.00          1   5937  555.0  150.0
# 6         0          86522          159.00          1  12308  360.0  150.0
# 9         0          86536          117.00          1  17399  111.0  150.0
# 15        0          86618           57.95          1   7055  555.0  150.0
# 18        0          86725           47.95          1   4663  490.0  150.0
# 20        0          86761           39.00          1   7875  314.0  150.0
# 23        0          86808          107.95          1   2392  360.0  150.0
# 27        0          86972           47.95          1  11307  321.0  150.0
#
#     card4  card5  card6  addr1  addr2  dist1
# 0     1.0  142.0    1.0  315.0   87.0   19.0
# 2     2.0  166.0    0.0  330.0   87.0  287.0
# ...

# %%
dados_aux.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c73d4113ea62> in <module>
# ----> 1 dados_aux.shape
#
# NameError: name 'dados_aux' is not defined

# %%
dados_aux.to_csv('train_transaction_')
