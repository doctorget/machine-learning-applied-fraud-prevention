# %%
import pandas as pd

# %%
dados.drop('TransactionID', axis= 1, inplace = True)

# %%
dados = pd.read_csv('dados/train_transaction.csv')
dados.head(10)
# Out:
#    TransactionID  isFraud  TransactionDT  TransactionAmt ProductCD  card1  \
# 0        2987000        0          86400            68.5         W  13926
# 1        2987001        0          86401            29.0         W   2755
# 2        2987002        0          86469            59.0         W   4663
# 3        2987003        0          86499            50.0         W  18132
# 4        2987004        0          86506            50.0         H   4497
# 5        2987005        0          86510            49.0         W   5937
# 6        2987006        0          86522           159.0         W  12308
# 7        2987007        0          86529           422.5         W  12695
# 8        2987008        0          86535            15.0         H   2803
# 9        2987009        0          86536           117.0         W  17399
#
#    card2  card3       card4  card5  ... V330  V331  V332  V333  V334 V335  \
# 0    NaN  150.0    discover  142.0  ...  NaN   NaN   NaN   NaN   NaN  NaN
# ...

# %% [markdown]
# ## Tirando amostra extratificada

# %%
dados_aux = pd.DataFrame(dados[['isFraud', 'TransactionDT', 'TransactionAmt', 'ProductCD', 'card1', 'card2', 'card3', 'card4', 'card5', 'card6','addr1','addr2','dist1',]])

# %%
dados_aux.notnull().sum()
# Out:
# isFraud           590540
# TransactionDT     590540
# TransactionAmt    590540
# ProductCD         590540
# card1             590540
# card2             581607
# card3             588975
# card4             588963
# card5             586281
# card6             588969
# addr1             524834
# addr2             524834
# dist1             238269
# dtype: int64

# %%
selecao = (dados_aux['addr2'].isnull())
dados_aux[selecao].head(20)
# Out:
#      isFraud  TransactionDT  TransactionAmt ProductCD  card1  card2  card3  \
# 10         0          86549          75.887         C  16496  352.0  117.0
# 11         0          86555          16.495         C   4461  375.0  185.0
# 40         0          87209          75.887         C  13329  569.0  117.0
# 48         0          87317          42.294         C  15885  545.0  185.0
# 49         0          87317           3.595         C  12730  266.0  185.0
# 68         0          87667           3.081         C  14076  545.0  185.0
# 72         0          87752           6.767         C  13832  375.0  185.0
# 74         0          87775          27.793         C  15885  545.0  185.0
# 79         0          87839          28.699         C   4504  500.0  185.0
# 84         0          87928         125.674         C   5583  103.0  185.0
# 85         0          87935          42.596         C  15885  545.0  185.0
# ...

# %%
s = dados_aux[dados_aux['dist1'].notnull()]

# %%
type(s)
# Out:
# pandas.core.frame.DataFrame

# %%
s['ProductCD'].value_counts()
# Out:
# W    238269
# Name: ProductCD, dtype: int64

# %% [markdown]
# ## Tratando Nulos

# %%
dados_aux = dados_aux.fillna({'dist1':dados_aux['dist1'].mean(), 'addr1':dados_aux['addr1'].median(), 'addr2':dados_aux['addr2'].median()})

# %%
dados_aux
# Out:
#         isFraud  TransactionDT  TransactionAmt ProductCD  card1  card2  card3  \
# 0             0          86400           68.50         W  13926    NaN  150.0
# 1             0          86401           29.00         W   2755  404.0  150.0
# 2             0          86469           59.00         W   4663  490.0  150.0
# 3             0          86499           50.00         W  18132  567.0  150.0
# 4             0          86506           50.00         H   4497  514.0  150.0
# ...         ...            ...             ...       ...    ...    ...    ...
# 590535        0       15811047           49.00         W   6550    NaN  150.0
# 590536        0       15811049           39.50         W  10444  225.0  150.0
# 590537        0       15811079           30.95         W  12037  595.0  150.0
# 590538        0       15811088          117.00         W   7826  481.0  150.0
# 590539        0       15811131          279.95         W  15066  170.0  150.0
#
# ...

# %%
dados_aux['dist1'].median()
# Out:
# 118.50218030881064

# %%
dados_aux.head()
# Out:
#    isFraud  TransactionDT  TransactionAmt ProductCD  card1  card2  card3  \
# 0        0          86400            68.5         W  13926    NaN  150.0
# 1        0          86401            29.0         W   2755  404.0  150.0
# 2        0          86469            59.0         W   4663  490.0  150.0
# 3        0          86499            50.0         W  18132  567.0  150.0
# 4        0          86506            50.0         H   4497  514.0  150.0
#
#         card4  card5   card6  addr1  addr2      dist1
# 0    discover  142.0  credit  315.0   87.0   19.00000
# 1  mastercard  102.0  credit  325.0   87.0  118.50218
# 2        visa  166.0   debit  330.0   87.0  287.00000
# 3  mastercard  117.0   debit  476.0   87.0  118.50218
# 4  mastercard  102.0  credit  420.0   87.0  118.50218

# %%
dados_aux.isnull().sum()
# Out:
# isFraud              0
# TransactionDT        0
# TransactionAmt       0
# ProductCD            0
# card1                0
# card2             8933
# card3             1565
# card4             1577
# card5             4259
# card6             1571
# addr1                0
# addr2                0
# dist1                0
# dtype: int64

# %%
selecao = (dados_aux['card2'].notnull()) & (dados_aux['card3'].notnull())  & (dados_aux['card4'].notnull()) & (dados_aux['card5'].notnull()) & (dados_aux['card6'].notnull())
dados_aux = dados_aux[selecao]

# %%
selecao = dados_aux['card2'].notnull()
dados_aux[selecao]
# Out:
#         isFraud  TransactionDT  TransactionAmt ProductCD  card1  card2  card3  \
# 1             0          86401          29.000         W   2755  404.0  150.0
# 2             0          86469          59.000         W   4663  490.0  150.0
# 3             0          86499          50.000         W  18132  567.0  150.0
# 4             0          86506          50.000         H   4497  514.0  150.0
# 5             0          86510          49.000         W   5937  555.0  150.0
# ...         ...            ...             ...       ...    ...    ...    ...
# 590534        0       15811030          67.505         C   5812  408.0  185.0
# 590536        0       15811049          39.500         W  10444  225.0  150.0
# 590537        0       15811079          30.950         W  12037  595.0  150.0
# 590538        0       15811088         117.000         W   7826  481.0  150.0
# 590539        0       15811131         279.950         W  15066  170.0  150.0
#
# ...

# %%
dados_aux[dados_aux['card6'].notnull()]
# Out:
#         isFraud  TransactionDT  TransactionAmt ProductCD  card1  card2  card3  \
# 1             0          86401          29.000         W   2755  404.0  150.0
# 2             0          86469          59.000         W   4663  490.0  150.0
# 3             0          86499          50.000         W  18132  567.0  150.0
# 4             0          86506          50.000         H   4497  514.0  150.0
# 5             0          86510          49.000         W   5937  555.0  150.0
# ...         ...            ...             ...       ...    ...    ...    ...
# 590534        0       15811030          67.505         C   5812  408.0  185.0
# 590536        0       15811049          39.500         W  10444  225.0  150.0
# 590537        0       15811079          30.950         W  12037  595.0  150.0
# 590538        0       15811088         117.000         W   7826  481.0  150.0
# 590539        0       15811131         279.950         W  15066  170.0  150.0
#
# ...

# %% [markdown]
# ## Categorizando colunas

# %%
a_trocar = {
    'discover': 1,
    'visa':2,
    'mastercard':3,
    'american express':4
}
dados_aux.card4 = dados_aux.card4.map(a_trocar)
# Out:
# C:\Users\samusilv\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:5208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
dados_aux
# Out:
#         isFraud  TransactionDT  TransactionAmt ProductCD  card1  card2  card3  \
# 1             0          86401          29.000         W   2755  404.0  150.0
# 2             0          86469          59.000         W   4663  490.0  150.0
# 3             0          86499          50.000         W  18132  567.0  150.0
# 4             0          86506          50.000         H   4497  514.0  150.0
# 5             0          86510          49.000         W   5937  555.0  150.0
# ...         ...            ...             ...       ...    ...    ...    ...
# 590534        0       15811030          67.505         C   5812  408.0  185.0
# 590536        0       15811049          39.500         W  10444  225.0  150.0
# 590537        0       15811079          30.950         W  12037  595.0  150.0
# 590538        0       15811088         117.000         W   7826  481.0  150.0
# 590539        0       15811131         279.950         W  15066  170.0  150.0
#
# ...

# %%
trocar = {
    'credit':1,
    'debit':0
}
dados_aux.card6 = dados_aux.card6.map(trocar)
dados_aux.head(10)
# Out:
#     isFraud  TransactionDT  TransactionAmt ProductCD  card1  card2  card3  \
# 1         0          86401          29.000         W   2755  404.0  150.0
# 2         0          86469          59.000         W   4663  490.0  150.0
# 3         0          86499          50.000         W  18132  567.0  150.0
# 4         0          86506          50.000         H   4497  514.0  150.0
# 5         0          86510          49.000         W   5937  555.0  150.0
# 6         0          86522         159.000         W  12308  360.0  150.0
# 7         0          86529         422.500         W  12695  490.0  150.0
# 8         0          86535          15.000         H   2803  100.0  150.0
# 9         0          86536         117.000         W  17399  111.0  150.0
# 10        0          86549          75.887         C  16496  352.0  117.0
#
#     card4  card5  card6  addr1  addr2      dist1
# 1       3  102.0    1.0  325.0   87.0  118.50218
# 2       2  166.0    0.0  330.0   87.0  287.00000
# ...

# %%
dados_aux.ProductCD.value_counts()
# Out:
# W    430447
# C     67619
# R     37171
# H     32733
# S     11528
# Name: ProductCD, dtype: int64

# %%
troca = {
    'W':1,
    'C':2,
    'R':3,
    'H':4,
    'S':5
    
}

dados_aux.ProductCD = dados_aux.ProductCD.map(troca)

# %%
dados_aux.value_count().isnull()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-8a8439e03670> in <module>
# ----> 1 dados_aux.value_count().isnull()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'value_count'

# %%
dados_aux.to_csv('train_transaction_clean', sep=';', index=False)

# %%
dados_aux.drop(10, axis = 0, inplace = True)

# %%
dados_aux

# %%
selecao = (dados_aux['addr2'] == 87)
dados_aux.head(20)

# %%
dados_aux.to_csv('train_transaction_clean.csv', sep=';', index=False)

# %% [markdown]
# ## removendo os outliers

# %%
selecao = (dados_aux['card2'].notnull()) & (dados_aux['card3'].notnull())  & (dados_aux['card4'].notnull()) & (dados_aux['card5'].notnull()) & (dados_aux['card6'].notnull())
dados_aux = dados_aux[selecao]

# %%
dados_aux.to_csv('train_transaction_clean.csv', sep=';', index=False)

# %%
dados_aux.head(15)

# %%
dados_aux.boxplot(['TransactionAmt'])

# %%
dados_aux[dados_aux['TransactionAmt'] > 7000]

# %%
valor = dados_aux['TransactionAmt']

# %%
Q1 = valor.quantile(.25)
Q3 = valor.quantile(.75)
IIQ = Q3 - Q1
limite_inferior = Q1 - 1.5 * IIQ
limite_superior = Q3 + 1.5 * IIQ

# %%
selecao = (valor >= limite_inferior) & (valor <= limite_superior)
dados_new = dados_aux[selecao]

# %%
dados_new.boxplot(['TransactionAmt'])

# %%
dados.hist(['TransactionAmt'])
dados_new.hist(['TransactionAmt'])

# %%
dados_aux.boxplot(['TransactionAmt'], by = ['card4'])

# %%
dados_new.boxplot(['TransactionAmt'], by = ['card4'])

# %%
dados_new.boxplot(['card1'], by = ['card4'])

# %%
valor = dados_new['card1']
Q1 = valor.quantile(.25)
Q3 = valor.quantile(.75)
IIQ = Q3 - Q1
limite_inferior = Q1 - 1.5 * IIQ
limite_superior = Q3 + 1.5 * IIQ

# %%
selecao = (valor >= limite_inferior) & (valor <= limite_superior)
dados_new = dados_new[selecao]

# %%
dados_new.boxplot(['card1'], by = ['card4'])

# %%
dados_new.boxplot(['card1'], by = ['card4'])
